# %% [markdown]
# ## Pandas
# * Pandas is a data-manipulation library.

# %% [markdown]
# ### Importing pandas

# %%
import numpy as np
import pandas as pd

# %%
type(pd)
# Out:
# module

# %% [markdown]
# ## Series (1-d)

# %% [markdown]
# ### Creating a Series

# %%
# creating a list:
animals = ["Dog", "Lion", "Tiger", "Fox", "Elephant", 3, np.nan]

# creating a Series using list:
animals_series = pd.Series(data=animals)
animals_series
# Out:
# 0         Dog
# 1        Lion
# 2       Tiger
# 3         Fox
# 4    Elephant
# 5           3
# 6         NaN
# dtype: object

# %% [markdown]
# #### Shape of the series

# %%
# Shape:
animals_series.shape
# Out:
# (7,)

# %% [markdown]
# #### Datatype of the series

# %%
# Datatype:
animals_series.dtypes
# Out:
# dtype('O')

# %% [markdown]
# #### Null values

# %%
animals_series.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# values:
animals_series.values
# Out:
# array(['Dog', 'Lion', 'Tiger', 'Fox', 'Elephant', 3, nan], dtype=object)

# %%
# index:
animals_series.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
# how many null values in the series:
print(animals_series.isna().sum())
# Out:
# 1

# %% [markdown]
# #### Describe the series

# %%
animals_series.describe()
# Out:
# count       6
# unique      6
# top       Dog
# freq        1
# dtype: object

# %% [markdown]
# ### Creating Series with custom index

# %%
days = ["mon", "tue", "wed", "thu", "fri"]
breakfast = ["pongal", "chappathi", "idly", "dosai", "pongal"]

breakfast_series = pd.Series(index=days, data=breakfast)
breakfast_series
# Out:
# mon       pongal
# tue    chappathi
# wed         idly
# thu        dosai
# fri       pongal
# dtype: object

# %% [markdown]
# #### Adding a string to all the data

# %%
breakfast_series_1 = breakfast_series + " Panimalar"
breakfast_series_1
# Out:
# mon       pongal Panimalar
# tue    chappathi Panimalar
# wed         idly Panimalar
# thu        dosai Panimalar
# fri       pongal Panimalar
# dtype: object

# %% [markdown]
# #### Adding a list of strings to the data correspondingly

# %%
sidemenu = ["sambar", "kurma", "sambar", "sambar", "sambar"]

breakfast_series_2 = breakfast_series + " " + sidemenu
breakfast_series_2
# Out:
# mon      pongal sambar
# tue    chappathi kurma
# wed        idly sambar
# thu       dosai sambar
# fri      pongal sambar
# dtype: object

# %% [markdown]
# ### Creating a series using dictionary

# %%
sports = {"Football":"Spain", "NBA":"USA", "Cricket":"India", "Kabadi":"Bangladesh", 0:"Pakistan"}
sports_series = pd.Series(data=sports)
sports_series
# Out:
# Football         Spain
# NBA                USA
# Cricket          India
# Kabadi      Bangladesh
# 0             Pakistan
# dtype: object

# %%
# index of the series:
sports_series.index
# Out:
# Index(['Football', 'NBA', 'Cricket', 'Kabadi', 0], dtype='object')

# %%
# values of the series:
sports_series.values
# Out:
# array(['Spain', 'USA', 'India', 'Bangladesh', 'Pakistan'], dtype=object)

# %% [markdown]
# ### Data slicing (loc & iloc)

# %%
# index position:
sports_series.iloc[0]
# Out:
# 'Spain'

# %%
sports_series.iloc[1:4]
# Out:
# NBA               USA
# Cricket         India
# Kabadi     Bangladesh
# dtype: object

# %%
# index name:
sports_series.loc[0]
# Out:
# 'Pakistan'

# %%
sports_series.loc["NBA":0]
# Out:
# NBA               USA
# Cricket         India
# Kabadi     Bangladesh
# 0            Pakistan
# dtype: object

# %% [markdown]
# ## DataFrame (2-d)

# %% [markdown]
# ### Creating a dataframe:

# %%
meals = [
    ["pongal", "sambar_rice"],
    ["chappathi", "chicken_rice"],
    ["idly", "briyani"],
    ["dosai", "egg_rice"],
    ["pongal", "rasam_rice"]
]

meals_index = ["mon", "tue", "wed", "thu", "fri"]
meals_columns = ["breakfast", "lunch"]

panimalar_df = pd.DataFrame(data=meals, index=meals_index, columns=meals_columns)
panimalar_df
# Out:
#      breakfast         lunch
# mon     pongal   sambar_rice
# tue  chappathi  chicken_rice
# wed       idly       briyani
# thu      dosai      egg_rice
# fri     pongal    rasam_rice

# %% [markdown]
# ### Creating a new column

# %%
snacks = ["coffee_cake", "tea_biscut", "coffee_cake", "tea_biscut", "coffee_biscut"]

# creating a new column:
panimalar_df["snacks"] = snacks
panimalar_df
# Out:
#      breakfast         lunch         snacks
# mon     pongal   sambar_rice    coffee_cake
# tue  chappathi  chicken_rice     tea_biscut
# wed       idly       briyani    coffee_cake
# thu      dosai      egg_rice     tea_biscut
# fri     pongal    rasam_rice  coffee_biscut

# %% [markdown]
# ### Creating a dataframe using dictionary

# %%
dic = {"mon":["pongal", "rice", "coffee"],
       "tue":["chappathi", "chicken", "tea"],
       "wed":["idly", "briyani", "coffee"],
       "thu":["dosai", "egg", "tea"],
       "fri":["pongal", "sambar", "coffee"],
       "sat":["idly", "rasam", "tea"]}

index = ["breakfast", "lunch", "snacks"]

df2 = pd.DataFrame(data=dic, index=index)
df2
# Out:
#               mon        tue      wed    thu     fri    sat
# breakfast  pongal  chappathi     idly  dosai  pongal   idly
# lunch        rice    chicken  briyani    egg  sambar  rasam
# snacks     coffee        tea   coffee    tea  coffee    tea

# %%
# transpose the data:
df3 = df2.T
df3
# Out:
#      breakfast    lunch  snacks
# mon     pongal     rice  coffee
# tue  chappathi  chicken     tea
# wed       idly  briyani  coffee
# thu      dosai      egg     tea
# fri     pongal   sambar  coffee
# sat       idly    rasam     tea

# %% [markdown]
# ### Importing a csv file:

# %%
# reading a csv file:
data = pd.read_csv("D:/03. Python/datasets/Automobile_data.csv", delimiter=",")

# top n rows:
data.head(3)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
#
# [3 rows x 26 columns]

# %%
# bottom n rows:
data.tail(3)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 202         mpfi  3.58    2.87               8.8        134      5500
# 203          idi  3.01     3.4              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 202       18          23  21485
# 203       26          27  22470
# 204       19          25  22625
#
# [3 rows x 26 columns]

# %% [markdown]
# ### Shape of the data

# %%
# shape of the dataframe:
data.shape
# Out:
# (205, 26)

# %% [markdown]
# ### Names of the column

# %%
# columns:
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ### Index names

# %%
# index:
data.index
# Out:
# RangeIndex(start=0, stop=205, step=1)

# %% [markdown]
# ### Size of the data

# %%
# size:
data.size
# Out:
# 5330

# %% [markdown]
# ### Basic information about the data

# %%
# information:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %% [markdown]
# ### Accessing columns

# %%
# taking a single column:
data[["length"]]
# Out:
#      length
# 0     168.8
# 1     168.8
# 2     171.2
# 3     176.6
# 4     176.6
# ..      ...
# 200   188.8
# 201   188.8
# 202   188.8
# 203   188.8
# 204   188.8
#
# [205 rows x 1 columns]

# %%
# taking multiple columns:
data[['length', 'width', 'height']]
# Out:
#      length  width  height
# 0     168.8   64.1    48.8
# 1     168.8   64.1    48.8
# 2     171.2   65.5    52.4
# 3     176.6   66.2    54.3
# 4     176.6   66.4    54.3
# ..      ...    ...     ...
# 200   188.8   68.9    55.5
# 201   188.8   68.8    55.5
# 202   188.8   68.9    55.5
# 203   188.8   68.9    55.5
# 204   188.8   68.9    55.5
#
# [205 rows x 3 columns]

# %% [markdown]
# ### Datatypes of columns

# %%
# datatypes of each column:
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# datatype of a particular column:
data["highway-mpg"].dtype
# Out:
# dtype('int64')

# %%
# datatypes of multiple column:
data[['length', 'width', 'height']].dtypes
# Out:
# length    float64
# width     float64
# height    float64
# dtype: object

# %% [markdown]
# ### Splitting columns into numeric and categoric:

# %%
num_col = [] #->int and float
cate_col = [] #->string(object)

for column in data.columns:
    if data[column].dtype=="object":
        cate_col.append(column)
    else:
        num_col.append(column)

print(f"Numeric columns: {num_col}\nCategoric columns: {cate_col}")
# Out:
# Numeric columns: ['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg']
# Categoric columns: ['normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']

# %%
# create two dataframe:

# num_df:
num_df = data[num_col]

# cate_df:
cate_df = data[cate_col]

# %%
num_df
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0            3        88.6   168.8   64.1    48.8         2548          130
# 1            3        88.6   168.8   64.1    48.8         2548          130
# 2            1        94.5   171.2   65.5    52.4         2823          152
# 3            2        99.8   176.6   66.2    54.3         2337          109
# 4            2        99.4   176.6   66.4    54.3         2824          136
# ..         ...         ...     ...    ...     ...          ...          ...
# 200         -1       109.1   188.8   68.9    55.5         2952          141
# 201         -1       109.1   188.8   68.8    55.5         3049          141
# 202         -1       109.1   188.8   68.9    55.5         3012          173
# 203         -1       109.1   188.8   68.9    55.5         3217          145
# 204         -1       109.1   188.8   68.9    55.5         3062          141
#
#      compression-ratio  city-mpg  highway-mpg
# 0                  9.0        21           27
# 1                  9.0        21           27
# 2                  9.0        19           26
# 3                 10.0        24           30
# 4                  8.0        18           22
# ..                 ...       ...          ...
# 200                9.5        23           28
# 201                8.7        19           25
# 202                8.8        18           23
# 203               23.0        26           27
# 204                9.5        19           25
#
# [205 rows x 10 columns]

# %% [markdown]
# ### describe() method

# %%
num_df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2145.000000    97.000000           8.600000   19.000000    25.000000
# 50%    2414.000000   120.000000           9.000000   24.000000    30.000000
# 75%    2935.000000   141.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %%
cate_df.describe()
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                205     205       205        205          205        205
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  41      32       185        168          114         96
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system  \
# count           205             205         205              205         205
# unique            3               2           7                7           8
# top             fwd           front         ohc             four        mpfi
# freq            120             202         148              159          94
#
#         bore stroke horsepower peak-rpm price
# count    205    205        205      205   205
# unique    39     37         60       24   187
# top     3.62    3.4         68     5500     ?
# freq      23     20         19       37     4

# %% [markdown]
# ### Dropping a column and a row

# %%
data.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# #### columns

# %%
# dropping a particular column:
data.drop(["normalized-losses"], axis=1, inplace=True)
data.head()
# Out:
#    symboling         make fuel-type aspiration num-of-doors   body-style  \
# 0          3  alfa-romero       gas        std          two  convertible
# 1          3  alfa-romero       gas        std          two  convertible
# 2          1  alfa-romero       gas        std          two    hatchback
# 3          2         audi       gas        std         four        sedan
# 4          2         audi       gas        std         four        sedan
#
#   drive-wheels engine-location  wheel-base  length  ...  engine-size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# 3          fwd           front        99.8   176.6  ...          109
# 4          4wd           front        99.4   176.6  ...          136
#
#    fuel-system  bore stroke compression-ratio  horsepower peak-rpm city-mpg  \
# 0         mpfi  3.47   2.68               9.0         111     5000       21
# 1         mpfi  3.47   2.68               9.0         111     5000       21
# 2         mpfi  2.68   3.47               9.0         154     5000       19
# 3         mpfi  3.19    3.4              10.0         102     5500       24
# 4         mpfi  3.19    3.4               8.0         115     5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 25 columns]

# %%
# dropping multiple columns:
data.drop(["symboling","make"], axis=1, inplace=True)
data.head()
# Out:
#   fuel-type aspiration num-of-doors   body-style drive-wheels engine-location  \
# 0       gas        std          two  convertible          rwd           front
# 1       gas        std          two  convertible          rwd           front
# 2       gas        std          two    hatchback          rwd           front
# 3       gas        std         four        sedan          fwd           front
# 4       gas        std         four        sedan          4wd           front
#
#    wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 0        88.6   168.8   64.1    48.8  ...          130        mpfi  3.47
# 1        88.6   168.8   64.1    48.8  ...          130        mpfi  3.47
# 2        94.5   171.2   65.5    52.4  ...          152        mpfi  2.68
# 3        99.8   176.6   66.2    54.3  ...          109        mpfi  3.19
# 4        99.4   176.6   66.4    54.3  ...          136        mpfi  3.19
#
#    stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 0    2.68               9.0        111     5000        21          27  13495
# 1    2.68               9.0        111     5000        21          27  16500
# 2    3.47               9.0        154     5000        19          26  16500
# 3     3.4              10.0        102     5500        24          30  13950
# 4     3.4               8.0        115     5500        18          22  17450
#
# [5 rows x 23 columns]

# %% [markdown]
# #### rows

# %%
# dropping a particular row:
data.drop([0], axis=0, inplace=True)
data.head()
# Out:
#   fuel-type aspiration num-of-doors   body-style drive-wheels engine-location  \
# 1       gas        std          two  convertible          rwd           front
# 2       gas        std          two    hatchback          rwd           front
# 3       gas        std         four        sedan          fwd           front
# 4       gas        std         four        sedan          4wd           front
# 5       gas        std          two        sedan          fwd           front
#
#    wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 1        88.6   168.8   64.1    48.8  ...          130        mpfi  3.47
# 2        94.5   171.2   65.5    52.4  ...          152        mpfi  2.68
# 3        99.8   176.6   66.2    54.3  ...          109        mpfi  3.19
# 4        99.4   176.6   66.4    54.3  ...          136        mpfi  3.19
# 5        99.8   177.3   66.3    53.1  ...          136        mpfi  3.19
#
#    stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 1    2.68               9.0        111     5000        21          27  16500
# 2    3.47               9.0        154     5000        19          26  16500
# 3     3.4              10.0        102     5500        24          30  13950
# 4     3.4               8.0        115     5500        18          22  17450
# 5     3.4               8.5        110     5500        19          25  15250
#
# [5 rows x 23 columns]

# %%
# dropping multiple rows:
data.drop([1,2,3,4,5], axis=0, inplace=True)
data.head()
# Out:
#    fuel-type aspiration num-of-doors body-style drive-wheels engine-location  \
# 6        gas        std         four      sedan          fwd           front
# 7        gas        std         four      wagon          fwd           front
# 8        gas      turbo         four      sedan          fwd           front
# 9        gas      turbo          two  hatchback          4wd           front
# 10       gas        std          two      sedan          rwd           front
#
#     wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 6        105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 7        105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 8        105.8   192.7   71.4    55.9  ...          131        mpfi  3.13
# 9         99.5   178.2   67.9    52.0  ...          131        mpfi  3.13
# 10       101.2   176.8   64.8    54.3  ...          108        mpfi   3.5
#
#     stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 6      3.4               8.5        110     5500        19          25  17710
# 7      3.4               8.5        110     5500        19          25  18920
# 8      3.4               8.3        140     5500        17          20  23875
# 9      3.4               7.0        160     5500        16          22      ?
# 10     2.8               8.8        101     5800        23          29  16430
#
# [5 rows x 23 columns]

# %% [markdown]
# ### loc and iloc

# %%
data.head()
# Out:
#    fuel-type aspiration num-of-doors body-style drive-wheels engine-location  \
# 6        gas        std         four      sedan          fwd           front
# 7        gas        std         four      wagon          fwd           front
# 8        gas      turbo         four      sedan          fwd           front
# 9        gas      turbo          two  hatchback          4wd           front
# 10       gas        std          two      sedan          rwd           front
#
#     wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 6        105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 7        105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 8        105.8   192.7   71.4    55.9  ...          131        mpfi  3.13
# 9         99.5   178.2   67.9    52.0  ...          131        mpfi  3.13
# 10       101.2   176.8   64.8    54.3  ...          108        mpfi   3.5
#
#     stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 6      3.4               8.5        110     5500        19          25  17710
# 7      3.4               8.5        110     5500        19          25  18920
# 8      3.4               8.3        140     5500        17          20  23875
# 9      3.4               7.0        160     5500        16          22      ?
# 10     2.8               8.8        101     5800        23          29  16430
#
# [5 rows x 23 columns]

# %% [markdown]
# #### loc[row, col]

# %%
data.loc[[6,7,8,9,10], ["fuel-type","aspiration","num-of-doors"]]
# Out:
#    fuel-type aspiration num-of-doors
# 6        gas        std         four
# 7        gas        std         four
# 8        gas      turbo         four
# 9        gas      turbo          two
# 10       gas        std          two

# %%
data.loc[7:12, "length":"engine-size"]
# Out:
#     length  width  height  curb-weight engine-type num-of-cylinders  \
# 7    192.7   71.4    55.7         2954         ohc             five
# 8    192.7   71.4    55.9         3086         ohc             five
# 9    178.2   67.9    52.0         3053         ohc             five
# 10   176.8   64.8    54.3         2395         ohc             four
# 11   176.8   64.8    54.3         2395         ohc             four
# 12   176.8   64.8    54.3         2710         ohc              six
#
#     engine-size
# 7           136
# 8           131
# 9           131
# 10          108
# 11          108
# 12          164

# %% [markdown]
# #### iloc[row, col]

# %%
data.iloc[0:5, 7:9]
# Out:
#     length  width
# 6    192.7   71.4
# 7    192.7   71.4
# 8    192.7   71.4
# 9    178.2   67.9
# 10   176.8   64.8

# %%
data.iloc[[0,5,9,7,6], [0,8,6,4,5]]
# Out:
#    fuel-type  width  wheel-base drive-wheels engine-location
# 6        gas   71.4       105.8          fwd           front
# 11       gas   64.8       101.2          rwd           front
# 15       gas   66.9       103.5          rwd           front
# 13       gas   64.8       101.2          rwd           front
# 12       gas   64.8       101.2          rwd           front

# %% [markdown]
# ### Reset index

# %%
data.head()
# Out:
#    fuel-type aspiration num-of-doors body-style drive-wheels engine-location  \
# 6        gas        std         four      sedan          fwd           front
# 7        gas        std         four      wagon          fwd           front
# 8        gas      turbo         four      sedan          fwd           front
# 9        gas      turbo          two  hatchback          4wd           front
# 10       gas        std          two      sedan          rwd           front
#
#     wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 6        105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 7        105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 8        105.8   192.7   71.4    55.9  ...          131        mpfi  3.13
# 9         99.5   178.2   67.9    52.0  ...          131        mpfi  3.13
# 10       101.2   176.8   64.8    54.3  ...          108        mpfi   3.5
#
#     stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 6      3.4               8.5        110     5500        19          25  17710
# 7      3.4               8.5        110     5500        19          25  18920
# 8      3.4               8.3        140     5500        17          20  23875
# 9      3.4               7.0        160     5500        16          22      ?
# 10     2.8               8.8        101     5800        23          29  16430
#
# [5 rows x 23 columns]

# %%
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#   fuel-type aspiration num-of-doors body-style drive-wheels engine-location  \
# 0       gas        std         four      sedan          fwd           front
# 1       gas        std         four      wagon          fwd           front
# 2       gas      turbo         four      sedan          fwd           front
# 3       gas      turbo          two  hatchback          4wd           front
# 4       gas        std          two      sedan          rwd           front
#
#    wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 0       105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 1       105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 2       105.8   192.7   71.4    55.9  ...          131        mpfi  3.13
# 3        99.5   178.2   67.9    52.0  ...          131        mpfi  3.13
# 4       101.2   176.8   64.8    54.3  ...          108        mpfi   3.5
#
#    stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 0     3.4               8.5        110     5500        19          25  17710
# 1     3.4               8.5        110     5500        19          25  18920
# 2     3.4               8.3        140     5500        17          20  23875
# 3     3.4               7.0        160     5500        16          22      ?
# 4     2.8               8.8        101     5800        23          29  16430
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Renaming the column and index

# %% [markdown]
# #### Column

# %%
data.rename(columns={"fuel-type":"FUEL TYPE", "aspiration":"ASPIRATION"}, inplace=True)
data.head()
# Out:
#   FUEL TYPE ASPIRATION num-of-doors body-style drive-wheels engine-location  \
# 0       gas        std         four      sedan          fwd           front
# 1       gas        std         four      wagon          fwd           front
# 2       gas      turbo         four      sedan          fwd           front
# 3       gas      turbo          two  hatchback          4wd           front
# 4       gas        std          two      sedan          rwd           front
#
#    wheel-base  length  width  height  ...  engine-size fuel-system  bore  \
# 0       105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 1       105.8   192.7   71.4    55.7  ...          136        mpfi  3.19
# 2       105.8   192.7   71.4    55.9  ...          131        mpfi  3.13
# 3        99.5   178.2   67.9    52.0  ...          131        mpfi  3.13
# 4       101.2   176.8   64.8    54.3  ...          108        mpfi   3.5
#
#    stroke compression-ratio horsepower peak-rpm  city-mpg highway-mpg  price
# 0     3.4               8.5        110     5500        19          25  17710
# 1     3.4               8.5        110     5500        19          25  18920
# 2     3.4               8.3        140     5500        17          20  23875
# 3     3.4               7.0        160     5500        16          22      ?
# 4     2.8               8.8        101     5800        23          29  16430
#
# [5 rows x 23 columns]

# %% [markdown]
# #### index

# %%
data.rename(index={0:"first_index", 1:"second_index"}, inplace=True)
data.head()
# Out:
#              FUEL TYPE ASPIRATION num-of-doors body-style drive-wheels  \
# first_index        gas        std         four      sedan          fwd
# second_index       gas        std         four      wagon          fwd
# 2                  gas      turbo         four      sedan          fwd
# 3                  gas      turbo          two  hatchback          4wd
# 4                  gas        std          two      sedan          rwd
#
#              engine-location  wheel-base  length  width  height  ...  \
# first_index            front       105.8   192.7   71.4    55.7  ...
# second_index           front       105.8   192.7   71.4    55.7  ...
# 2                      front       105.8   192.7   71.4    55.9  ...
# 3                      front        99.5   178.2   67.9    52.0  ...
# 4                      front       101.2   176.8   64.8    54.3  ...
#
#               engine-size fuel-system  bore  stroke compression-ratio  \
# first_index           136        mpfi  3.19     3.4               8.5
# second_index          136        mpfi  3.19     3.4               8.5
# 2                     131        mpfi  3.13     3.4               8.3
# 3                     131        mpfi  3.13     3.4               7.0
# 4                     108        mpfi   3.5     2.8               8.8
#
#              horsepower peak-rpm  city-mpg highway-mpg  price
# first_index         110     5500        19          25  17710
# second_index        110     5500        19          25  18920
# 2                   140     5500        17          20  23875
# 3                   160     5500        16          22      ?
# 4                   101     5800        23          29  16430
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Check missing values:

# %%
data.isna()
# Out:
#               FUEL TYPE  ASPIRATION  num-of-doors  body-style  drive-wheels  \
# first_index       False       False         False       False         False
# second_index      False       False         False       False         False
# 2                 False       False         False       False         False
# 3                 False       False         False       False         False
# 4                 False       False         False       False         False
# ...                 ...         ...           ...         ...           ...
# 194               False       False         False       False         False
# 195               False       False         False       False         False
# 196               False       False         False       False         False
# 197               False       False         False       False         False
# 198               False       False         False       False         False
#
#               engine-location  wheel-base  length  width  height  ...  \
# first_index             False       False   False  False   False  ...
# second_index            False       False   False  False   False  ...
# 2                       False       False   False  False   False  ...
# 3                       False       False   False  False   False  ...
# 4                       False       False   False  False   False  ...
# ...                       ...         ...     ...    ...     ...  ...
# 194                     False       False   False  False   False  ...
# 195                     False       False   False  False   False  ...
# 196                     False       False   False  False   False  ...
# 197                     False       False   False  False   False  ...
# 198                     False       False   False  False   False  ...
#
#               engine-size  fuel-system   bore  stroke  compression-ratio  \
# first_index         False        False  False   False              False
# second_index        False        False  False   False              False
# 2                   False        False  False   False              False
# 3                   False        False  False   False              False
# 4                   False        False  False   False              False
# ...                   ...          ...    ...     ...                ...
# 194                 False        False  False   False              False
# 195                 False        False  False   False              False
# 196                 False        False  False   False              False
# 197                 False        False  False   False              False
# 198                 False        False  False   False              False
#
#               horsepower  peak-rpm  city-mpg  highway-mpg  price
# first_index        False     False     False        False  False
# second_index       False     False     False        False  False
# 2                  False     False     False        False  False
# 3                  False     False     False        False  False
# 4                  False     False     False        False  False
# ...                  ...       ...       ...          ...    ...
# 194                False     False     False        False  False
# 195                False     False     False        False  False
# 196                False     False     False        False  False
# 197                False     False     False        False  False
# 198                False     False     False        False  False
#
# [199 rows x 23 columns]

# %%
data.isna().any()
# Out:
# FUEL TYPE            False
# ASPIRATION           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke               False
# compression-ratio    False
# horsepower           False
# peak-rpm             False
# city-mpg             False
# highway-mpg          False
# price                False
# dtype: bool

# %%
data.isna().sum()
# Out:
# FUEL TYPE            0
# ASPIRATION           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64
